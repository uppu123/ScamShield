# %% [markdown]
# # 01 - Explore EMSCAD
#
# Load and inspect the Employment Scam Aegean Dataset. Run `python scripts/download_emscad.py` first to fetch the CSV.

# %%
import pandas as pd

df = pd.read_csv("../data/raw/emscad.csv")
df.head()

# %%
df["fraudulent"].value_counts(normalize=True)

# Imbalanced? If so, consider class weights or oversampling in training.
